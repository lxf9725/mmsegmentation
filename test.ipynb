# %%
from mmseg.apis import init_model, inference_model,show_result_pyplot
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image

# %%
img_path='data\\potsdam\\ann_dir\\train\\2_10_0_0_512_512.png'

# %%
config_path='configs\\fcn\\fcn_r50-d8_4xb2-40k_potsdam-512x512.py'
checkpoint_path='E:\\DataSet\\mmsegmentation_work_dirs_copy\\fcn_r50-d8_4xb2-40k_potsdam-512x512\\iter_40000.pth'

# %%
model=init_model(config_path,checkpoint_path)

# %%
result=inference_model(model,img_path)

# %%
print(result['predictions'])

# %%
a=result.gt_sem_seg

# %%
vis_image=show_result_pyplot(model,img_path,result)

# %%
vis_aimage=show_result_pyplot(img='data\\potsdam\\ann_dir\\train\\2_10_0_0_512_512.png',draw_gt=True,draw_pred=False)

# %%
vis_image=show_result_pyplot(model,img_path,result,out_file='result.png',draw_pred=False,opacity=1.0)

# %%
img=Image.open('graph\\deeplabv3plus\\potsdam\\pred\\00000000_pred.png')
plt.imshow(img)

# %%
img=Image.open('data\\vaihingen\\ann_dir\\val\\area29_1405_0_1917_512.png')
plt.imshow(img)
